# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("option_paths.csv", header=None)
df
# Out:
#          0        1        2        3        4        5        6        7    \
# 0    4.39167  4.34605  4.44407  4.42659  4.50299  4.53068  4.51546  4.53041
# 1    4.39167  4.35706  4.26312  4.37233  4.38934  4.44399  4.41732  4.46913
# 2    4.39167  4.33642  4.33548  4.38407  4.30979  4.30638  4.41094  4.45531
# 3    4.39167  4.38149  4.38191  4.41553  4.39001  4.40135  4.40654  4.45868
# 4    4.39167  4.44256  4.49295  4.53597  4.53995  4.55351  4.65832  4.64705
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 995  4.39167  4.38750  4.40780  4.31856  4.32112  4.26324  4.28963  4.28712
# 996  4.39167  4.46339  4.46532  4.43615  4.51561  4.50486  4.55063  4.60953
# 997  4.39167  4.42260  4.42079  4.37609  4.43968  4.41083  4.43867  4.36377
# 998  4.39167  4.40506  4.32400  4.28365  4.21814  4.25509  4.24515  4.20591
# 999  4.39167  4.35593  4.33926  4.32792  4.33123  4.35721  4.42346  4.47416
#
# ...

# %%
df.T.plot(legend=False, figsize=(16, 9), title="1000 Sample Option Paths")
# Out:
# <AxesSubplot:title={'center':'1000 Sample Option Paths'}>

# %%
df = pd.read_csv("stock_paths.csv", header=None)
df
# Out:
#      0         1         2         3         4         5         6    \
# 0    100   99.8932  100.1220  100.0810  100.2580  100.3210  100.2860
# 1    100   99.9191   99.6974   99.9548   99.9946  100.1220  100.0600
# 2    100   99.8706   99.8684   99.9822   99.8079   99.7998  100.0450
# 3    100   99.9762   99.9772  100.0560   99.9961  100.0230  100.0350
# 4    100  100.1180  100.2350  100.3330  100.3420  100.3730  100.6110
# ..   ...       ...       ...       ...       ...       ...       ...
# 995  100   99.9903  100.0380   99.8286   99.8346   99.6976   99.7602
# 996  100  100.1660  100.1710  100.1030  100.2870  100.2620  100.3670
# 997  100  100.0720  100.0680   99.9636  100.1120  100.0450  100.1090
# 998  100  100.0310   99.8414   99.7461   99.5902   99.6783   99.6546
# 999  100   99.9164   99.8773   99.8506   99.8584   99.9194  100.0740
#
#           7         8         9    ...      92       93       94       95   \
# ...

# %%
df.T.plot(legend=False, figsize=(16, 9), title="1000 Sample Stock Paths")
# Out:
# <AxesSubplot:title={'center':'1000 Sample Stock Paths'}>
